# %% [markdown]
# ## Plotly Dash - Cara Membuat Sebuah Dropdown Selector Component di Dash Plotly (Part 2)
#
# Berikut ini cara membuat sebuah dropdown selector component di Dash Plotly.

# %%
#memasukan modul yang digunakan
import dash
import dash_core_components as dcc
import dash_html_components as html

# %%
#mendefinisikan app
app = dash.Dash()

# %%
#mengisi konten pada dashboard
app.layout = html.Div([
    html.Label('Pilih Kota'), 
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [
            {'label' : 'San Francisco', 'value' : 'SF'},
            {'label' : 'New York City', 'value' : 'NYC'},
            {'label' : 'Raleigh Durham', 'value' : 'RDU'}
        ], 
        value = 'NYC'
    )
])

# %%
#melihat hasil dashboard
if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Dec/2019 15:00:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2019 15:00:06] "GET /_dash-component-suites/dash_renderer/react@16.8.6.min.js?v=1.0.1&m=1568095493 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2019 15:00:06] "GET /_dash-component-suites/dash_renderer/prop-types@15.7.2.min.js?v=1.0.1&m=1568095493 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2019 15:00:06] "GET /_dash-component-suites/dash_renderer/react-dom@16.8.6.min.js?v=1.0.1&m=1568095493 HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Dec/2019 15:00:06] "GET /_dash-component-suites/dash_html_components/dash_html_components.min.js?v=1.0.1&m=1568095500 HTTP/1.1" 200 -
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                         #Semoga Bermanfaat
#                                         #@Raspiani_
