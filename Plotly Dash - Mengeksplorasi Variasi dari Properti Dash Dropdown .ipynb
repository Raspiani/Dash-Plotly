# %% [markdown]
# ## Plotly Dash - Mengeksplorasi Variasi dari Properti Dash Dropdown
# Berikut ini hasil mengeksplorasi variasi dari properti dash dropdown.

# %%
#memasukan modul yang digunakan
import dash
import dash_core_components as dcc
import dash_html_components as html

# %%
#mendefinisikan app
app = dash.Dash()

# %%
#mengisi konten pada dashboard
app.layout = html.Div([
    html.Label('Pilih Kota'), 
    dcc.Dropdown(
        id = 'first-dropdown',
        options = [
            {'label' : 'San Francisco', 'value' : 'SF'},
            {'label' : 'New York City', 'value' : 'NYC'},
            {'label' : 'Raleigh Durham', 'value' : 'RDU', 'disabled' : True}
        ], 
        value = 'NYC',
        multi = True
        placeholder = 'Pilih Kota Disini'
        #disabled = True
        
    )
])
# Out:
#   File "<ipython-input-14-7658eaf62474>", line 13
#     placeholder = 'Pilih Kota Disini'
#               ^
# SyntaxError: invalid syntax

# %%
#melihat hasil dashboard
if __name__ == '__main__':
    app.run_server(port=4050)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4050/ (Press CTRL+C to quit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                         #Semoga Bermanfaat
#                                         #@Raspiani_
